# %% [markdown]
# # Fundamentals of Programming 110 Fall Program 5 Student ID:1104526 Name：陳品佑

# %% [markdown]
# # Problem 1. How many and bigest
# We want to write some simple procedures that work on dictionaries to return information.<br>
# <br>
# animals = { 'a': \['aardvark'], 'b': ['baboon'], 'c': ['coati']}<br>
#
# animals['b'].append('buffalo')<br>
# animals['c'].append('crocodile')<br>
# animals['c'].append('crow')<br>
# animals['d'] = ['donkey']<br>
# animals['d'].append('dingo')<br>
# animals['d'].append('dolphin')<br>
# <br>
# First, write a procedure, called how_many, which returns the sum of the number of values associated with a dictionary. <br>
# ### For example:
# print(how_many(animals))<br>
# 9<br>
# <br>
# Second, we want to write some simple procedures that work on dictionaries to return information. <br>
# This time, write a procedure, called bigest, which returns the key corresponding to the entry with the bigest number of values associated with it. If there is more than one such entry, return any one of the matching keys.<br>
# ### Example usage:
# bigest(animals) <br>
# 'd' <br>
# If there are no values in the dictionary, bigest should return None.
#
# 我們想寫一些簡單的程式來處理字典以傳回一些信息。<br>
# <br>
# animals = { 'a': \['aardvark'], 'b': ['baboon'], 'c': ['coati']}<br>
#
# animals['b'].append('buffalo')<br>
# animals['c'].append('crocodile')<br>
# animals['c'].append('crow')<br>
# animals['d'] = ['donkey']<br>
# animals['d'].append('dingo')<br>
# animals['d'].append('dolphin')<br>
# <br>
# 首先，寫一個名為 how_many 的方程式，傳回與字典有關聯的所有項目之數量總和。 <br>
# ### 例如：
# print(how_many(animals))<br>
# 9<br>
# <br>
# 其次，我們要寫一些簡單的程序來處理字典以傳回一些信息。 <br>
# 這一次，寫一個名為 bigest 的方程式，傳回其對應含有最多項目的鍵值。 如果有多個這樣的鍵值，則傳回任何一個匹配的鍵值。<br>
# ### 例如:
# bigest(animals) <br>
# 'd' <br>
# 如果字典中沒有這個值，bigest 應該傳回 None。

# %%
# Problem 1
# Name: Your name
# Time: 3:30 
# ... your code goes here ... 
animals = { 'a': ['aardvark'], 'b': ['baboon'], 'c': ['coati']}
animals['b'].append('buffalo')
animals['c'].append('crocodile')
animals['c'].append('crow')
animals['d'] = ['donkey']
animals['d'].append('dingo')
animals['d'].append('dolphin')
    

def how_many(aDict):
    '''
    aDict: A dictionary, where all the values are lists.
    returns: int, how many values are in the dictionary.
    '''
    # Your Code Here
    c=0
    for k in aDict:
        c+=len(aDict[k])
    return c
print(how_many(animals))

def bigest(aDict):
    '''
    aDict: A dictionary, where all the values are lists.
    returns: The key with the smallest number of values associated with it
    '''
    # Your Code Here
    test=[]
    c=0
    for u in aDict:
        test.append(aDict[u])
        if len(test)>c:
            c=len(test)
    return c
print(bigest(animals))
# Out:
# 9
# 4

# %%
animals = { 'a': ['aardvark'], 'b': ['baboon'], 'c': ['coati']}
animals['b'].append('buffalo')
animals['c'].append('crocodile')
animals['c'].append('crow')
animals['d'] = ['donkey']
animals['d'].append('dingo')
animals['d'].append('dolphin')
    
print(how_many(animals))
print(bigest(animals))

# %% [markdown]
# # Problem 2. Mean, variance, range, and  mean standard error(平均數、變異數、範圍與平均數的標準誤)
#
# The mean, variance, range, and mean standard error are commonly used values in statistics. Design a function, enter a sequence of numbers (list), and return these values. The mean value is equal to the sum of all values divided by the sample number; the variance is calculated by square of each value subtracting the mean, adding them up, and then divided by the sample number minus one; the range is equal to the maximum value minus the minimum value; the mean standard error is equal to the standard deviation (the square root of the variance) divided by the square root of the sample number. The input and output instructions are as follows:<br>
# Your code must be iterative-functions such as sum() and mean(), etc. are not allowed. <br>
#
# Input description:<br>
# A sequence of numbers: \[35, 10, 15, 30, 20, 40, 25, 30, 10, 30\]<br>
# Output description:<br>
# Mean: 24.5<br>
# Variation: 108.056<br>
# Range: 30<br>
# Mean Standard error: 3.287
#
# 平均數、變異數、範圍與平均數的標準誤是統計學中常用的數值。設計一個方程式，輸入一序列數字(list)，並回傳這些值，平均值等於所有值累加後除以其個數；變異數是先計算每個值減去平均的平方，全部相加之後再除以總數減一；範圍等於最大值減去最小值；平均數的標準誤等於標準差(變異數開根號)除以樣本數開根號。輸出入說明如下：<br>
# 你的程式碼必須是迭代的-不允許使用sum(), mean()等函式。<br>
#
# 輸入說明：<br>
# 一序列數字：\[35, 10, 15, 30, 20, 40, 25, 30, 10, 30\]<br>
# 輸出說明：<br>
# 平均數: 24.5<br>
# 變異數: 108.056<br>
# 範圍：30<br>
# 平均數的標準誤：3.287

# %%
# Problem 2
# Name: Your name
# Time: 3:30 
# ... your code goes here ... 

def describe(L):
    """
    """
    s=0
    for x in range(0,len(L)):
        s+=L[x]
    mean=s/len(L)
    s=0
    for x in range(0,len(L)):
        s+=(L[x]-mean)**2
    var=s/(len(L)-1)
    L.sort()
    ran=L[len(L)-1]-L[0]
    mse=(var**0.5)/(len(L)**0.5)
    return (mean, var, ran, mse) 

L=[35, 10, 15, 30, 20, 40, 25, 399, 10, 30]
(me, va, ra, ms)= describe(L)
print("平均數:", me)
print("變異數:", va)
print("範圍：", ra)
print("平均數的標準誤：", ms)
# Out:
# 平均數: 61.4
# 變異數: 14175.155555555559
# 範圍： 389
# 平均數的標準誤： 37.64990777618925

# %%
L=[35, 10, 15, 30, 20, 40, 25, 30, 10, 30]
(me, va, ra, ms)= describe(L)
print("平均數:", me)
print("變異數:", va)
print("範圍：", ra)
print("平均數的標準誤：", ms)

# %% [markdown]
# # Problem 3. Deposit and Withdrawal (存存提提)
# There are many customers in Xipipi Bank, and many customers come to deposit and withdraw money every day. <br>
# With deposits and withdrawals, bank managers are confused about how much money each client has in his account. <br>
# Write a program to help the bank process customer transaction data! <br>
# <br>
# Enter description<br>
# The first column: an integer N, which means there are N customers. N <= 100<br>
# The second column: an integer T, which means there are T transactions. T <= 10000<br>
# Then column T: three integers n, t, m. On behalf of the nth customer, m yuan was deposited or withdrawn. t=1 stands for deposit; t=2 stands for withdrawal; t=3 stands for newly opened account; t=4 stands for closing account (only 0 yuan in the account can be closed). <br>
# Assuming that the customer number is 0 ~ N-1, each customer's account initially stores 0 yuan. <br>
# Output description<br>
# After all transactions, what is the deposit of each customer. The deposit can be negative. <br>
# Finally calculate the sum of all bank customer deposits<br>
# <br>
# 西批批銀行有很多顧客，每天都有許多客戶前來存款、提款。<br>
# 存存提提下，銀行經理都搞混每個客戶到底帳戶裡有多少錢了。<br>
# 寫一個程式，幫忙銀行處理客戶的交易資料吧！<br>
# <br>
# 輸入說明<br>
# 第一列：一個整數N，代表有N個顧客。 N <= 100<br>
# 第二列：一個整數T，代表有T筆交易。 T <= 10000<br>
# 接著T列：三個整數n、t、m。代表第n名顧客，存款或提款了m元。 t=1代表存款；t=2代表提款；t=3代表新開帳號；t=4代表關閉帳號(帳號內0元才可關閉)。<br>
# 假設顧客編號是 0 ~ N-1，每名顧客帳戶一開始存有 0 元。<br>
# 輸出說明<br>
# 經過所有交易後，每名顧客的存款為多少。存款可以是負的。<br>
# 最後計算所有銀行顧客存款之總和<br>
# <br>
# input<br>
# 5<br>
# 10<br>
# 0 1 1000<br>
# 4 2 600<br>
# 2 1 200<br>
# 1 1 10000<br>
# 0 2 400<br>
# 2 2 100<br>
# 0 2 300<br>
# 5 3 100<br>
# 6 3 200<br>
# 3 4 0<br>
# output<br>
# 0 : 300<br>
# 1 : 10000<br>
# 2 : 100<br>
# 4 : -600<br>
# 5 : 100<br>
# 6 : 200<br>
# 10100

# %%
# Problem 3
# Name: Your name
# Time: 3:30 
# ... your code goes here ... 

N=int(input("顧客數目:"))
T=int(input("交易數目:"))
t=T
o=""
m=[]
p=[]
total=0
while T>0:
    o+=input()
    m.append(int(o[0]))
    m.append(int(o[2]))
    m.append(int(o[4:len(o)]))
    o=""
    T-=1
C={x:x*0 for x in range(0,N)}
while t>0:
    p=m[0:3]
    if p[1]==1:
        C[p[0]]+=p[2]
    elif p[1]==2:
        C[p[0]]-=p[2]
    elif p[1]==3:
        a={p[0]:p[2]}
        C.update(a)
    elif p[1]==4 and C[p[0]]==0:
        del C[p[0]]
    del m[0:3]
    p=[]
    t-=1
v=list(C.values())
for x in range(0,len(v)):
    total+=v[x]
print(C)
print("存款總和:",total)
# Out:
# {0: 300, 1: 10000, 2: 100, 4: -600, 5: 100, 6: 200}
# 存款總和: 10100

# %% [markdown]
# # Problem 4. Student Data Processing System (學生資料處理系統)
# Use the python dictionary structure to design a simple student data processing system. The functions include adding, deleting, querying, modifying, printing, and exit.<br>
# 利用python dictionary結構設計一個簡單學生資料處理系統，功能包括新增、刪除、查詢、修改、列印、離開。<br>
#
# ## Data structure description (資料結構說明)：<br>
# s={'s01':86, 's02': 72, 's03':80, 's04':100, ...}<br>
#
# ## 畫面設計
# 1. 新增:
# 2. 刪除:
# 3. 查詢:
# 4. 修改:
# 5. 列印出學生總數及其總平均:
# 6. 列印出成績最高及最低的學生：
# 7. 離開
#
# 你的選擇:______
#
# ## Screen Design
# 1. Added:
# 2. Delete:
# 3. Inquiry:
# 4. Modify:
# 5. Print out the total number of students and their total average:
# 6. Print out the students with the highest and lowest grades:
# 7. Exit
#
# your choice:______
#
# ## 畫面或功能說明
# 1. 新增:可新增一個學生資料(先判斷學生資料是否在dictionary結構中)
# 2. 刪除:可刪除一個學生資料(先查詢學生資料是否在dictionary結構中，再詢問是否確認刪除，確認後刪除)
# 3. 查詢:可查詢一個學生資料(列印出該學生之分數)
# 4. 修改:可修改一個學生資料(先查詢出學生資料，再給予輸入新的成績修改)
# 5. 列印出學生總數及其總平均:可列印所有學生的人數及總平均資料
# 6. 列印出成績最高及最低的學生：可列印出成績最高及最低的學生編號
# 7. 離開
#
# ## Screen or function description
# 1. Add: You can add a student data (first determine whether the student data is in the dictionary structure)
# 2. Delete: You can delete a student data (first check whether the student data is in the dictionary structure, and then ask whether to confirm the deletion, and then delete it after confirmation)
# 3. Query: You can query a student's information (print out the student's score)
# 4. Modify: you can modify a student's data (first check out the student's data, and then enter the new grade to modify)
# 5. Print the total number of students and their total average: print the number of all students and the total average data
# 6. Print out students with the highest and lowest grades: print out the student numbers with the highest and lowest grades
# 7. Exit

# %%
# Problem 4
# 副程式
# Name: Your name
# Time: 3:30 
# ... your code goes here ... 


def insert(s):
    id = input("Enter a student id to be added:")
    if id not in list(s.keys()):
        grade = int(input("Enter a student grade to add:")) 
        s[id] = grade
    else:
        print(id+"has been existed!")    
    
def delete(s):
    id = input("Enter a student id to be deleted:")
    if id not in s:
        print(id+" does not exist!") 
    else:
        del(s[id])
def search(s):
    id=input("Enter a student id to be searched:")
    if id not in s:
        print("this id dosen't exist!")
    else:
        print(s[id])
def modify(s):
    id=input("Enter a student id to be modified:")
    if id not in s:
        print("this id dosen't exist!")
    else:
        grade=int(input("Enter a student grade to modify:"))
        s[id]=grade
def total_avg(s):
    sum=0
    t=list(s.values())
    for x in range(0,len(t)):
        sum+=t[x]
    print("Total number of students:",len(t))
    print("average:",sum/len(t))
def high_low(s):
    k=list(s.keys())
    v=list(s.values())
    h=max(v)
    l=min(v)
    p=v.index(h)
    print("higest:",k[p])
    p=v.index(l)
    print("lowest:",k[p])

# %%
# 接著是主程式
# Name: Your name
# Time: 3:30 
# ... your code goes here ... 
s={'s01':86, 's02': 72, 's03':80, 's04':100}
def insert(s):
    id = input("Enter a student id to be added:")
    if id not in list(s.keys()):
        grade = int(input("Enter a student grade to add:")) 
        s[id] = grade
    else:
        print(id+"has been existed!")    
    
def delete(s):
    id = input("Enter a student id to be deleted:")
    if id not in s:
        print(id+" does not exist!") 
    else:
        del(s[id])
def search(s):
    id=input("Enter a student id to be searched:")
    if id not in s:
        print("this id dosen't exist!")
    else:
        print(s[id])
def modify(s):
    id=input("Enter a student id to be modified:")
    if id not in s:
        print("this id dosen't exist!")
    else:
        grade=int(input("Enter a student grade to modify:"))
        s[id]=grade
def total_avg(s):
    sum=0
    t=list(s.values())
    for x in range(0,len(t)):
        sum+=t[x]
    print("Total number of students:",len(t))
    print("average:",sum/len(t))
def high_low(s):
    k=list(s.keys())
    v=list(s.values())
    h=max(v)
    l=min(v)
    p=v.index(h)
    print("higest:",k[p])
    p=v.index(l)
    print("lowest:",k[p])

while True:
    print("1. 新增:")
    print("2. 刪除:")
    print("3. 查詢:")
    print("4. 修改:")
    print("5. 列印出學生總數及其總平均::")
    print("6. 列印出成績最高及最低的學生:")
    print("7. 離開")   
    choice = input("你的選擇:")
    
    if choice == '7':
        break
    elif choice == '1':
        insert(s)
    elif choice == '2':
        delete(s)
    elif choice=="3":
        search(s)
    elif choice=="4":
        modify(s)
    elif choice=="5":
        total_avg(s)
    elif choice=="6":
        high_low(s)
# Out:
# 1. 新增:
# 2. 刪除:
# 3. 查詢:
# 4. 修改:
# 5. 列印出學生總數及其總平均::
# 6. 列印出成績最高及最低的學生:
# 7. 離開
# 你的選擇:1
# Enter a student id to be added:s05
# Enter a student grade to add:45
# 1. 新增:
# 2. 刪除:
# 3. 查詢:
# 4. 修改:
# 5. 列印出學生總數及其總平均::
# 6. 列印出成績最高及最低的學生:
# 7. 離開
# 你的選擇:2
# Enter a student id to be deleted:s05
# 1. 新增:
# 2. 刪除:
# 3. 查詢:
# 4. 修改:
# 5. 列印出學生總數及其總平均::
# 6. 列印出成績最高及最低的學生:
# 7. 離開
# 你的選擇:3
# Enter a student id to be searched:s01
# 86
# 1. 新增:
# 2. 刪除:
# 3. 查詢:
# 4. 修改:
# 5. 列印出學生總數及其總平均::
# 6. 列印出成績最高及最低的學生:
# 7. 離開
# 你的選擇:5
# Total number of students: 4
# average: 84.5
# 1. 新增:
# 2. 刪除:
# 3. 查詢:
# 4. 修改:
# 5. 列印出學生總數及其總平均::
# 6. 列印出成績最高及最低的學生:
# 7. 離開
# 你的選擇:6
# higest: s04
# lowest: s02
# 1. 新增:
# 2. 刪除:
# 3. 查詢:
# 4. 修改:
# 5. 列印出學生總數及其總平均::
# 6. 列印出成績最高及最低的學生:
# 7. 離開
# 你的選擇:7
